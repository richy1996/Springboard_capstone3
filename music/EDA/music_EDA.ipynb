# %% [markdown]
# <a href="https://colab.research.google.com/github/richy1996/Springboard_capstone3/blob/main/music_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
# !sudo apt install -y fluidsynth
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fluid-soundfont-gm libevdev2 libfluidsynth3 libgudev-1.0-0 libinput-bin
#   libinput10 libinstpatch-1.0-2 libmd4c0 libmtdev1 libqt5core5a libqt5dbus5
#   libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5 libwacom-bin
#   libwacom-common libwacom9 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxkbcommon-x11-0 qsynth qt5-gtk-platformtheme qttranslations5-l10n
#   timgm6mb-soundfont
# Suggested packages:
#   fluid-soundfont-gs qt5-image-formats-plugins qtwayland5 jackd
# The following NEW packages will be installed:
#   fluid-soundfont-gm fluidsynth libevdev2 libfluidsynth3 libgudev-1.0-0
#   libinput-bin libinput10 libinstpatch-1.0-2 libmd4c0 libmtdev1 libqt5core5a
#   libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5 libwacom-bin
#   libwacom-common libwacom9 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxkbcommon-x11-0 qsynth qt5-gtk-platformtheme qttranslations5-l10n
#   timgm6mb-soundfont
# 0 upgraded, 32 newly installed, 0 to remove and 19 not upgraded.
# Need to get 148 MB of archives.
# After this operation, 207 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5core5a amd64 5.15.3+dfsg-2ubuntu0.2 [2,006 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmtdev1 amd64 1.1.6-1build4 [14.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-common all 2.2.0-1 [54.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom9 amd64 2.2.0-1 [22.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput-bin amd64 1.20.0-1ubuntu0.3 [19.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput10 amd64 1.20.0-1ubuntu0.3 [131 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmd4c0 amd64 0.4.8-1 [42.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5dbus5 amd64 5.15.3+dfsg-2ubuntu0.2 [222 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5network5 amd64 5.15.3+dfsg-2ubuntu0.2 [731 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5gui5 amd64 5.15.3+dfsg-2ubuntu0.2 [3,722 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5widgets5 amd64 5.15.3+dfsg-2ubuntu0.2 [2,561 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5svg5 amd64 5.15.3-1 [149 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fluid-soundfont-gm all 3.1-5.3 [130 MB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libinstpatch-1.0-2 amd64 1.1.6-1 [240 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 timgm6mb-soundfont all 1.3-5 [5,427 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfluidsynth3 amd64 2.2.5-1 [246 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fluidsynth amd64 2.2.5-1 [27.4 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-bin amd64 2.2.0-1 [13.6 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qsynth amd64 0.9.6-1 [305 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qt5-gtk-platformtheme amd64 5.15.3+dfsg-2ubuntu0.2 [130 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qttranslations5-l10n all 5.15.3-1 [1,983 kB]
# Fetched 148 MB in 3s (44.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 32.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libqt5core5a:amd64.
# (Reading database ... 120874 files and directories currently installed.)
# Preparing to unpack .../00-libqt5core5a_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../01-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmtdev1:amd64.
# Preparing to unpack .../02-libmtdev1_1.1.6-1build4_amd64.deb ...
# Unpacking libmtdev1:amd64 (1.1.6-1build4) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../03-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libwacom-common.
# Preparing to unpack .../04-libwacom-common_2.2.0-1_all.deb ...
# Unpacking libwacom-common (2.2.0-1) ...
# Selecting previously unselected package libwacom9:amd64.
# Preparing to unpack .../05-libwacom9_2.2.0-1_amd64.deb ...
# Unpacking libwacom9:amd64 (2.2.0-1) ...
# Selecting previously unselected package libinput-bin.
# Preparing to unpack .../06-libinput-bin_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput-bin (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libinput10:amd64.
# Preparing to unpack .../07-libinput10_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libmd4c0:amd64.
# Preparing to unpack .../08-libmd4c0_0.4.8-1_amd64.deb ...
# Unpacking libmd4c0:amd64 (0.4.8-1) ...
# Selecting previously unselected package libqt5dbus5:amd64.
# Preparing to unpack .../09-libqt5dbus5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5network5:amd64.
# Preparing to unpack .../10-libqt5network5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../11-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../12-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../13-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../14-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../15-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../16-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../17-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../18-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../19-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libqt5gui5:amd64.
# Preparing to unpack .../20-libqt5gui5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5widgets5:amd64.
# Preparing to unpack .../21-libqt5widgets5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../22-libqt5svg5_5.15.3-1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.15.3-1) ...
# Selecting previously unselected package fluid-soundfont-gm.
# Preparing to unpack .../23-fluid-soundfont-gm_3.1-5.3_all.deb ...
# Unpacking fluid-soundfont-gm (3.1-5.3) ...
# Selecting previously unselected package libinstpatch-1.0-2:amd64.
# Preparing to unpack .../24-libinstpatch-1.0-2_1.1.6-1_amd64.deb ...
# Unpacking libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Selecting previously unselected package timgm6mb-soundfont.
# Preparing to unpack .../25-timgm6mb-soundfont_1.3-5_all.deb ...
# Unpacking timgm6mb-soundfont (1.3-5) ...
# Selecting previously unselected package libfluidsynth3:amd64.
# Preparing to unpack .../26-libfluidsynth3_2.2.5-1_amd64.deb ...
# Unpacking libfluidsynth3:amd64 (2.2.5-1) ...
# Selecting previously unselected package fluidsynth.
# Preparing to unpack .../27-fluidsynth_2.2.5-1_amd64.deb ...
# Unpacking fluidsynth (2.2.5-1) ...
# Selecting previously unselected package libwacom-bin.
# Preparing to unpack .../28-libwacom-bin_2.2.0-1_amd64.deb ...
# Unpacking libwacom-bin (2.2.0-1) ...
# Selecting previously unselected package qsynth.
# Preparing to unpack .../29-qsynth_0.9.6-1_amd64.deb ...
# Unpacking qsynth (0.9.6-1) ...
# Selecting previously unselected package qt5-gtk-platformtheme:amd64.
# Preparing to unpack .../30-qt5-gtk-platformtheme_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package qttranslations5-l10n.
# Preparing to unpack .../31-qttranslations5-l10n_5.15.3-1_all.deb ...
# Unpacking qttranslations5-l10n (5.15.3-1) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up qttranslations5-l10n (5.15.3-1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libmtdev1:amd64 (1.1.6-1build4) ...
# Setting up libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libmd4c0:amd64 (0.4.8-1) ...
# Setting up fluid-soundfont-gm (3.1-5.3) ...
# update-alternatives: using /usr/share/sounds/sf2/FluidR3_GM.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/FluidR3_GM.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# Setting up timgm6mb-soundfont (1.3-5) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libfluidsynth3:amd64 (2.2.5-1) ...
# Setting up libwacom-common (2.2.0-1) ...
# Setting up libwacom9:amd64 (2.2.0-1) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libinput-bin (1.20.0-1ubuntu0.3) ...
# Setting up fluidsynth (2.2.5-1) ...
# Created symlink /etc/systemd/user/default.target.wants/fluidsynth.service → /usr/lib/systemd/user/fluidsynth.service.
# Setting up libwacom-bin (2.2.0-1) ...
# Setting up libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5svg5:amd64 (5.15.3-1) ...
# Setting up qsynth (0.9.6-1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install --upgrade pyfluidsynth
# Out:
# Collecting pyfluidsynth
#   Downloading pyFluidSynth-1.3.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyfluidsynth) (1.23.5)
# Installing collected packages: pyfluidsynth
# Successfully installed pyfluidsynth-1.3.2

# %%
# !pip install pretty_midi
# Out:
# Collecting pretty_midi
#   Downloading pretty_midi-0.2.10.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 31.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from pretty_midi) (1.23.5)
# Collecting mido>=1.1.16 (from pretty_midi)
#   Downloading mido-1.3.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pretty_midi) (1.16.0)
# Requirement already satisfied: packaging~=23.1 in /usr/local/lib/python3.10/dist-packages (from mido>=1.1.16->pretty_midi) (23.2)
# Building wheels for collected packages: pretty_midi
#   Building wheel for pretty_midi (setup.py) ... done
#   Created wheel for pretty_midi: filename=pretty_midi-0.2.10-py3-none-any.whl size=5592287 sha256=b1009c4b9bd6857d97d6dfb5da875e5e66f2bfd6cc01ba5771b3c386247e4a56
#   Stored in directory: /root/.cache/pip/wheels/cd/a5/30/7b8b7f58709f5150f67f98fde4b891ebf0be9ef07a8af49f25
# Successfully built pretty_midi
# Installing collected packages: mido, pretty_midi
# Successfully installed mido-1.3.0 pretty_midi-0.2.10

# %%
import collections
import datetime
import fluidsynth
import glob
import numpy as np
import pathlib
import pandas as pd
import pretty_midi
import seaborn as sns
import tensorflow as tf

from IPython import display
from matplotlib import pyplot as plt
from typing import Optional

# %% [markdown]
# # EDA

# %% [markdown]
# - Read data from disk, convert to tabular data and do exploratory data analysis

# %%
# copy the midis.zip file from google drive to current directory
# !cp /content/drive/MyDrive/midis.zip /content/

# %%
# unzip the midis.zip file
# !unzip /content/midis.zip
# Out:
# Archive:  /content/midis.zip
#    creating: content/midis/
#   inflating: content/midis/op87_04b.mid
#   inflating: content/midis/waltz_08.mid
#   inflating: content/midis/poissons.mid
#   inflating: content/midis/op6n09m4.mid
#   inflating: content/midis/maz25n3.mid
#   inflating: content/midis/bydlo.mid
#   inflating: content/midis/kinder5.mid
#   inflating: content/midis/rachmm6.mid
#   inflating: content/midis/waltz_03.mid
#   inflating: content/midis/dsch10-2.mid
#   inflating: content/midis/tristes2.mid
#   inflating: content/midis/hans3a.mid
#   inflating: content/midis/hmwoo23b.mid
#   inflating: content/midis/op6n08m3.mid
#   inflating: content/midis/satieson.mid
#   inflating: content/midis/beeth9-1.mid
#   inflating: content/midis/hmcello1.mid
#   inflating: content/midis/chpson3d.mid
#   inflating: content/midis/suite_3.mid
#   inflating: content/midis/adelina.mid
#   inflating: content/midis/schumann.mid
#   inflating: content/midis/bwv977.mid
#   inflating: content/midis/vs2-3and.mid
#   inflating: content/midis/mladi.mid
#   inflating: content/midis/poulcmo1.mid
#   inflating: content/midis/vp3-4min.mid
#   inflating: content/midis/rejoice.mid
#   inflating: content/midis/cs1-6gig.mid
#   inflating: content/midis/bwv849.mid
#   inflating: content/midis/sib2-2.mid
#   inflating: content/midis/lisztson.mid
#   inflating: content/midis/EspanjaCaphriccoCatalan.mid
#   inflating: content/midis/mnsnt02.mid
#   inflating: content/midis/mthmvwo2.mid
#   inflating: content/midis/op87_18b.mid
#   inflating: content/midis/bartrfd0.mid
#   inflating: content/midis/bwv830.mid
#   inflating: content/midis/han-fir5.mid
#   inflating: content/midis/op6n03m3.mid
#   inflating: content/midis/rvalkyri.mid
#   inflating: content/midis/ital-1.mid
#   inflating: content/midis/schi9004.mid
#   inflating: content/midis/bartok.mid
#   inflating: content/midis/bwv833.mid
#   inflating: content/midis/bwv853.mid
#   inflating: content/midis/mikro146.mid
#   inflating: content/midis/op87_13b.mid
#   inflating: content/midis/gfh-jm56.mid
#   inflating: content/midis/mikro147.mid
#   inflating: content/midis/ballo.mid
#   inflating: content/midis/gfh-jm38.mid
#   inflating: content/midis/mazrka26.mid
#   inflating: content/midis/adtesus.mid
#   inflating: content/midis/mthmwo4c.mid
#   inflating: content/midis/aida_ovt.mid
#   inflating: content/midis/chwa6402.mid
#   inflating: content/midis/hmmtop95.mid
#   inflating: content/midis/mthm107f.mid
#   inflating: content/midis/al_adagi.mid
#   inflating: content/midis/menop64b.mid
#   inflating: content/midis/bwv799.mid
#   inflating: content/midis/op6n03m5.mid
#   inflating: content/midis/bjss6l.mid
#   inflating: content/midis/chet1012.mid
#   inflating: content/midis/beet27m3.mid
#   inflating: content/midis/mahl4_3.mid
#   inflating: content/midis/hummop59.mid
#   inflating: content/midis/raging.mid
#   inflating: content/midis/sch-fan3.mid
#   inflating: content/midis/hum111-1.mid
#   inflating: content/midis/av-p323.mid
#   inflating: content/midis/bjsbmm20.mid
#   inflating: content/midis/duet140.mid
#   inflating: content/midis/op6n12m3.mid
#   inflating: content/midis/bwv1060c.mid
#   inflating: content/midis/waltz_01.mid
#   inflating: content/midis/mpprel-e.mid
#   inflating: content/midis/bjsbmm21.mid
#   inflating: content/midis/mikro141.mid
#   inflating: content/midis/bulgar6.mid
#   inflating: content/midis/bwv987.mid
#   inflating: content/midis/hwv333-6.mid
#   inflating: content/midis/gfh-jm09.mid
#   inflating: content/midis/pr37n2.mid
#   inflating: content/midis/ernani.mid
#   inflating: content/midis/taoh24e3.mid
#   inflating: content/midis/bjsbmm10.mid
#   inflating: content/midis/holberg1.mid
#   inflating: content/midis/air.mid
#   inflating: content/midis/coup8a.mid
#   inflating: content/midis/romance3.mid
#   inflating: content/midis/amin_c.mid
#   inflating: content/midis/flute-2.mid
#   inflating: content/midis/beet27m2.mid
#   inflating: content/midis/op6n11m1.mid
#   inflating: content/midis/mthmf123.mid
#   inflating: content/midis/ballade2.mid
#   inflating: content/midis/gadflyfolk.mid
#   inflating: content/midis/mikro037.mid
#   inflating: content/midis/hungdan6.mid
#   inflating: content/midis/op87_11a.mid
#   inflating: content/midis/op5-3c.mid
#   inflating: content/midis/fossiles.mid
#   inflating: content/midis/bjsbmm14.mid
#   inflating: content/midis/op6n03m2.mid
#   inflating: content/midis/sr15-12.mid
#   inflating: content/midis/bwv785.mid
#   inflating: content/midis/mensy3-3.mid
#   inflating: content/midis/strpetr.mid
#   inflating: content/midis/faurreq7.mid
#   inflating: content/midis/han-h2os.mid
#   inflating: content/midis/op87_13a.mid
#   inflating: content/midis/bwv784.mid
#   inflating: content/midis/chet1009.mid
#   inflating: content/midis/op87_14b.mid
#   inflating: content/midis/han4-6b.mid
#   inflating: content/midis/gtniaise.mid
#   inflating: content/midis/gmin_b.mid
#   inflating: content/midis/satsara3.mid
#   inflating: content/midis/chno3201.mid
#   inflating: content/midis/op6n01m5.mid
#   inflating: content/midis/waltz_13.mid
#   inflating: content/midis/op6n05m6.mid
#   inflating: content/midis/bjsbmm13.mid
#   inflating: content/midis/sr15-4.mid
#   inflating: content/midis/thesoft.mid
#   inflating: content/midis/hum111-3.mid
#   inflating: content/midis/pmtuiler.mid
#   inflating: content/midis/mensy3-2.mid
#   inflating: content/midis/mthm26b.mid
#   inflating: content/midis/gttrio.mid
#   inflating: content/midis/bwv976.mid
#   inflating: content/midis/beeth25.mid
#   inflating: content/midis/vivconct.mid
#   inflating: content/midis/6-4-2.mid
#   inflating: content/midis/satsara2.mid
#   inflating: content/midis/op6n11m4.mid
#   inflating: content/midis/4untous.mid
#   inflating: content/midis/zadok1.mid
#   inflating: content/midis/courting.mid
#   inflating: content/midis/mazrka43.mid
#   inflating: content/midis/pfc2-3.mid
#   inflating: content/midis/notturno.mid
#   inflating: content/midis/liszt1-1.mid
#   inflating: content/midis/beeth4_3.mid
#   inflating: content/midis/humm_t4.mid
#   inflating: content/midis/mthmwo4a.mid
#   inflating: content/midis/jshcg652.mid
#   inflating: content/midis/chno1503.mid
#   inflating: content/midis/lbtheme.mid
#   inflating: content/midis/kinder4.mid
#   inflating: content/midis/wag_wed.mid
#   inflating: content/midis/humm81m3.mid
#   inflating: content/midis/cs4-6gig.mid
#   inflating: content/midis/cs2-1pre.mid
#   inflating: content/midis/rejou.mid
#   inflating: content/midis/rkeaster.mid
#   inflating: content/midis/mthmop09.mid
#   inflating: content/midis/mazrka37.mid
#   inflating: content/midis/mikro101.mid
#   inflating: content/midis/meneli38.mid
#   inflating: content/midis/bwv795.mid
#   inflating: content/midis/bwv967.mid
#   inflating: content/midis/wafther.mid
#   inflating: content/midis/vs1-1ada.mid
#   inflating: content/midis/hpstrike.mid
#   inflating: content/midis/hindbsn2.mid
#   inflating: content/midis/bwv775.mid
#   inflating: content/midis/menv.mid
#   inflating: content/midis/tnfdm.mid
#   inflating: content/midis/poulcmo3.mid
#   inflating: content/midis/han4-5b.mid
#   inflating: content/midis/moveperp.mid
#   inflating: content/midis/mazrka01.mid
#   inflating: content/midis/mthuo74b.mid
#   inflating: content/midis/han4-5a.mid
#   inflating: content/midis/hans3d.mid
#   inflating: content/midis/op6n09m5.mid
#   inflating: content/midis/bwv872.mid
#   inflating: content/midis/hanarvar.mid
#   inflating: content/midis/jshcg653.mid
#   inflating: content/midis/sib2-1.mid
#   inflating: content/midis/bwv963.mid
#   inflating: content/midis/cs2-4sar.mid
#   inflating: content/midis/humop41p.mid
#   inflating: content/midis/op87_10a.mid
#   inflating: content/midis/bvhi.mid
#   inflating: content/midis/ital-2.mid
#   inflating: content/midis/jshcg654.mid
#   inflating: content/midis/bwv852.mid
#   inflating: content/midis/EspanjaPrelude.mid
#   inflating: content/midis/liebstrm.mid
#   inflating: content/midis/poem69n2.mid
#   inflating: content/midis/ballade1.mid
#   inflating: content/midis/jesu.mid
#   inflating: content/midis/liszt1-2.mid
#   inflating: content/midis/ballade3.mid
#   inflating: content/midis/cpf-come.mid
#   inflating: content/midis/hpipe2.mid
#   inflating: content/midis/rach_op30_3.mid
#   inflating: content/midis/mazrka34.mid
#   inflating: content/midis/mikro124.mid
#   inflating: content/midis/scripr10.mid
#   inflating: content/midis/rachmm2.mid
#   inflating: content/midis/latalant.mid
#   inflating: content/midis/dvs91.mid
#   inflating: content/midis/mazrka03.mid
#   inflating: content/midis/mikro125.mid
#   inflating: content/midis/waltz_16.mid
#   inflating: content/midis/cs4-5bou.mid
#   inflating: content/midis/mazrka40.mid
#   inflating: content/midis/pr37n1.mid
#   inflating: content/midis/op87_12b.mid
#   inflating: content/midis/bwv974.mid
#   inflating: content/midis/deb_rev.mid
#   inflating: content/midis/gp_moto.mid
#   inflating: content/midis/hummop16.mid
#   inflating: content/midis/bwv901.mid
#   inflating: content/midis/mewed.mid
#   inflating: content/midis/op87_12a.mid
#   inflating: content/midis/me19-1.mid
#   inflating: content/midis/vp1-3co.mid
#   inflating: content/midis/han-fir4.mid
#   inflating: content/midis/bouree.mid
#   inflating: content/midis/hmmd-601.mid
#   inflating: content/midis/scrsym33.mid
#   inflating: content/midis/sr15-6.mid
#   inflating: content/midis/vs2-2fug.mid
#   inflating: content/midis/pathet2.mid
#   inflating: content/midis/op5-3b.mid
#   inflating: content/midis/waltz_15.mid
#   inflating: content/midis/op6n04m2.mid
#   inflating: content/midis/fugue_1.mid
#   inflating: content/midis/bwv817.mid
#   inflating: content/midis/kinder2.mid
#   inflating: content/midis/op6n10m2.mid
#   inflating: content/midis/hums187.mid
#   inflating: content/midis/op6n12bm.mid
#   inflating: content/midis/shep.mid
#   inflating: content/midis/mikro126.mid
#   inflating: content/midis/barmspc4.mid
#   inflating: content/midis/bwv858.mid
#   inflating: content/midis/vp3-1pre.mid
#   inflating: content/midis/pagvr710.mid
#   inflating: content/midis/vstragic.mid
#   inflating: content/midis/bwv911.mid
#   inflating: content/midis/op87_03a.mid
#   inflating: content/midis/bwv854.mid
#   inflating: content/midis/bwv816.mid
#   inflating: content/midis/bwv802.mid
#   inflating: content/midis/bwv847.mid
#   inflating: content/midis/valseoub.mid
#   inflating: content/midis/rach1-1.mid
#   inflating: content/midis/bwv864.mid
#   inflating: content/midis/karinter.mid
#   inflating: content/midis/bwv982.mid
#   inflating: content/midis/mnsnt10.mid
#   inflating: content/midis/mthuso1a.mid
#   inflating: content/midis/sr15-5.mid
#   inflating: content/midis/mthmo120.mid
#   inflating: content/midis/op7n07m2.mid
#   inflating: content/midis/bwv879.mid
#   inflating: content/midis/lbvar2.mid
#   inflating: content/midis/mazrka25.mid
#   inflating: content/midis/op87_23a.mid
#   inflating: content/midis/gfh-jm60.mid
#   inflating: content/midis/r2310.mid
#   inflating: content/midis/butbrite.mid
#   inflating: content/midis/amin_b.mid
#   inflating: content/midis/beets3m1.mid
#   inflating: content/midis/be_roman.mid
#   inflating: content/midis/bwv992.mid
#   inflating: content/midis/cs3-2all.mid
#   inflating: content/midis/ltkije1.mid
#   inflating: content/midis/gfh-jm00.mid
#   inflating: content/midis/siegfrd.mid
#   inflating: content/midis/widor_to.mid
#   inflating: content/midis/sharp.mid
#   inflating: content/midis/spin-sng.mid
#   inflating: content/midis/bwv159-4.mid
#   inflating: content/midis/cs6-4sar.mid
#   inflating: content/midis/festivgs.mid
#   inflating: content/midis/riders.mid
#   inflating: content/midis/mahl4_1.mid
#   inflating: content/midis/locus-iste.mid
#   inflating: content/midis/op6n11m5.mid
#   inflating: content/midis/bwv880.mid
#   inflating: content/midis/scriabn2.mid
#   inflating: content/midis/shmuyle.mid
#   inflating: content/midis/bwv894.mid
#   inflating: content/midis/op87_01a.mid
#   inflating: content/midis/op6n04m3.mid
#   inflating: content/midis/mikro140.mid
#   inflating: content/midis/bwv801.mid
#   inflating: content/midis/cmaj_c.mid
#   inflating: content/midis/vp2-4gig.mid
#   inflating: content/midis/mazrka05.mid
#   inflating: content/midis/mthm107d.mid
#   inflating: content/midis/traumeri.mid
#   inflating: content/midis/hmmd-401.mid
#   inflating: content/midis/gfh-jm07.mid
#   inflating: content/midis/clangour.mid
#   inflating: content/midis/mazrka11.mid
#   inflating: content/midis/biz_arls.mid
#   inflating: content/midis/aida_ii2.mid
#   inflating: content/midis/chno5501.mid
#   inflating: content/midis/chno0902.mid
#   inflating: content/midis/mnsnt06.mid
#   inflating: content/midis/gfh-jm15.mid
#   inflating: content/midis/mthmop126.mid
#   inflating: content/midis/mephist1.mid
#   inflating: content/midis/mazrka12.mid
#   inflating: content/midis/cs5-1pre.mid
#   inflating: content/midis/piccdill.mid
#   inflating: content/midis/op6n10m4.mid
#   inflating: content/midis/prkson62.mid
#   inflating: content/midis/sch7.mid
#   inflating: content/midis/racp23-4.mid
#   inflating: content/midis/faurreq5.mid
#   inflating: content/midis/bwv780.mid
#   inflating: content/midis/mazrka47.mid
#   inflating: content/midis/sr15-7.mid
#   inflating: content/midis/pagavar9.mid
#   inflating: content/midis/bwv844.mid
#   inflating: content/midis/appspg13.mid
#   inflating: content/midis/bag6_10.mid
#   inflating: content/midis/largo1.mid
#   inflating: content/midis/bwv778.mid
#   inflating: content/midis/EspanjaZortzico.mid
#   inflating: content/midis/hans6c.mid
#   inflating: content/midis/mnsnt13.mid
#   inflating: content/midis/hmwoo23c.mid
#   inflating: content/midis/beets3m3.mid
#   inflating: content/midis/bwv986.mid
#   inflating: content/midis/hummop37.mid
#   inflating: content/midis/suite_2.mid
#   inflating: content/midis/cs1-1pre.mid
#   inflating: content/midis/kreuz1vc.mid
#   inflating: content/midis/liszthr2.mid
#   inflating: content/midis/bjsbmm18.mid
#   inflating: content/midis/bwv820.mid
#   inflating: content/midis/cs5-6gig.mid
#   inflating: content/midis/hummop67.mid
#   inflating: content/midis/all_his.mid
#   inflating: content/midis/bwv978.mid
#   inflating: content/midis/cpfpapi.mid
#   inflating: content/midis/brand61.mid
#   inflating: content/midis/poulenc.mid
#   inflating: content/midis/tanhausr.mid
#   inflating: content/midis/hmtpot58.mid
#   inflating: content/midis/sr-etude.mid
#   inflating: content/midis/op87_15a.mid
#   inflating: content/midis/bwv861.mid
#   inflating: content/midis/weber3a.mid
#   inflating: content/midis/bwv1032b.mid
#   inflating: content/midis/bwv903.mid
#   inflating: content/midis/taoh24e1.mid
#   inflating: content/midis/faurreq1.mid
#   inflating: content/midis/op6n10m5.mid
#   inflating: content/midis/hung3.mid
#   inflating: content/midis/gfh-jm58.mid
#   inflating: content/midis/bwv865.mid
#   inflating: content/midis/bjss6v.mid
#   inflating: content/midis/cs6-2all.mid
#   inflating: content/midis/mazrka24.mid
#   inflating: content/midis/hummtwo9.mid
#   inflating: content/midis/mazrka08.mid
#   inflating: content/midis/chet2501.mid
#   inflating: content/midis/bwv788.mid
#   inflating: content/midis/mazrka19.mid
#   inflating: content/midis/sngwow01.mid
#   inflating: content/midis/op87_20a.mid
#   inflating: content/midis/mhqop87a.mid
#   inflating: content/midis/carminab.mid
#   inflating: content/midis/hence.mid
#   inflating: content/midis/mnsnt04.mid
#   inflating: content/midis/lbvar5.mid
#   inflating: content/midis/btkconc2.mid
#   inflating: content/midis/br_hd-2.mid
#   inflating: content/midis/mthop3-1.mid
#   inflating: content/midis/mthm107e.mid
#   inflating: content/midis/deadmrch.mid
#   inflating: content/midis/bwv966.mid
#   inflating: content/midis/gf-romnc.mid
#   inflating: content/midis/cpf-bird.mid
#   inflating: content/midis/msw34.mid
#   inflating: content/midis/pagvar18.mid
#   inflating: content/midis/mthuso1c.mid
#   inflating: content/midis/bwv873.mid
#   inflating: content/midis/preludii.mid
#   inflating: content/midis/sonmv2.mid
#   inflating: content/midis/han4-4a.mid
#   inflating: content/midis/fugue_5.mid
#   inflating: content/midis/schezo.mid
#   inflating: content/midis/mazrka32.mid
#   inflating: content/midis/op6n11m3.mid
#   inflating: content/midis/beevar1.mid
#   inflating: content/midis/han-fir6.mid
#   inflating: content/midis/ogodwho.mid
#   inflating: content/midis/poem32n1.mid
#   inflating: content/midis/mazrka17.mid
#   inflating: content/midis/op7no6.mid
#   inflating: content/midis/hummop10.mid
#   inflating: content/midis/brand42s.mid
#   inflating: content/midis/mikro133.mid
#   inflating: content/midis/op87_03b.mid
#   inflating: content/midis/chet1010.mid
#   inflating: content/midis/bwv813.mid
#   inflating: content/midis/mazrka36.mid
#   inflating: content/midis/EspanjaTango.mid
#   inflating: content/midis/op6n08m4.mid
#   inflating: content/midis/largo.mid
#   inflating: content/midis/cloches.mid
#   inflating: content/midis/humop1-3.mid
#   inflating: content/midis/bwv984.mid
#   inflating: content/midis/bwv814.mid
#   inflating: content/midis/humm_t2.mid
#   inflating: content/midis/vs3-4alg.mid
#   inflating: content/midis/bwv856.mid
#   inflating: content/midis/bjsbmm07.mid
#   inflating: content/midis/mikro144.mid
#   inflating: content/midis/bwv877.mid
#   inflating: content/midis/coucou.mid
#   inflating: content/midis/mnsnt01.mid
#   inflating: content/midis/sr12-2.mid
#   inflating: content/midis/vp1-5sa.mid
#   inflating: content/midis/prkson61.mid
#   inflating: content/midis/machdich.mid
#   inflating: content/midis/mikro113.mid
#   inflating: content/midis/butoh.mid
#   inflating: content/midis/op87_21b.mid
#   inflating: content/midis/viv_pic.mid
#   inflating: content/midis/op87_07b.mid
#   inflating: content/midis/brand41s.mid
#   inflating: content/midis/scrsym31.mid
#   inflating: content/midis/personag.mid
#   inflating: content/midis/chno1501.mid
#   inflating: content/midis/hum-ph6.mid
#   inflating: content/midis/mikro130.mid
#   inflating: content/midis/finale.mid
#   inflating: content/midis/cs4-1pre.mid
#   inflating: content/midis/trioson4.mid
#   inflating: content/midis/chno0901.mid
#   inflating: content/midis/bjsbmm11.mid
#   inflating: content/midis/chpson3a.mid
#   inflating: content/midis/seraphim.mid
#   inflating: content/midis/spinrade.mid
#   inflating: content/midis/mendwed.mid
#   inflating: content/midis/chno2701.mid
#   inflating: content/midis/bwv774.mid
#   inflating: content/midis/cantique.mid
#   inflating: content/midis/fmaj_d.mid
#   inflating: content/midis/cmballet.mid
#   inflating: content/midis/fmaj_c.mid
#   inflating: content/midis/cmaj_a.mid
#   inflating: content/midis/forbehld.mid
#   inflating: content/midis/bwv782.mid
#   inflating: content/midis/walton5.mid
#   inflating: content/midis/bwv980.mid
#   inflating: content/midis/vp3-5bou.mid
#   inflating: content/midis/barimyst.mid
#   inflating: content/midis/gfh-jm03.mid
#   inflating: content/midis/arp.mid
#   inflating: content/midis/chet1008.mid
#   inflating: content/midis/me85-1.mid
#   inflating: content/midis/op87_24b.mid
#   inflating: content/midis/lions.mid
#   inflating: content/midis/serious.mid
#   inflating: content/midis/poultdp4.mid
#   inflating: content/midis/maschera.mid
#   inflating: content/midis/taof01.mid
#   inflating: content/midis/etuded.mid
#   inflating: content/midis/chet1004.mid
#   inflating: content/midis/blas1.mid
#   inflating: content/midis/vp1-1al.mid
#   inflating: content/midis/mthmop2b.mid
#   inflating: content/midis/mazrka35.mid
#   inflating: content/midis/tortues.mid
#   inflating: content/midis/J_C_Bach_Ach_dass_ich_Wassers_gnug_hatte.mid
#   inflating: content/midis/reflect.mid
#   inflating: content/midis/gfhblast.mid
#   inflating: content/midis/bwv1060a.mid
#   inflating: content/midis/jshcg656.mid
#   inflating: content/midis/op87_17b.mid
#   inflating: content/midis/mthmtrc1.mid
#   inflating: content/midis/bwv860.mid
#   inflating: content/midis/voliere.mid
#   inflating: content/midis/vs3-1ada.mid
#   inflating: content/midis/mazrka30.mid
#   inflating: content/midis/cs6-3cou.mid
#   inflating: content/midis/ballade4.mid
#   inflating: content/midis/bwv848.mid
#   inflating: content/midis/bjsbmm19.mid
#   inflating: content/midis/humop7-3.mid
#   inflating: content/midis/entrtanr.mid
#   inflating: content/midis/ch_w70_2.mid
#   inflating: content/midis/jig.mid
#   inflating: content/midis/abarbaro.mid
#   inflating: content/midis/orpheus.mid
#   inflating: content/midis/hmcello2.mid
#   inflating: content/midis/op6n10m1.mid
#   inflating: content/midis/carnaval.mid
#   inflating: content/midis/op6n01m2.mid
#   inflating: content/midis/schm2-3.mid
#   inflating: content/midis/han4-5c.mid
#   inflating: content/midis/scripr17.mid
#   inflating: content/midis/mthmwo3d.mid
#   inflating: content/midis/pagavar1.mid
#   inflating: content/midis/prelude2.mid
#   inflating: content/midis/bwv793.mid
#   inflating: content/midis/lszt_pe3.mid
#   inflating: content/midis/han-ct-1.mid
#   inflating: content/midis/gp_fwork.mid
#   inflating: content/midis/sonmv3.mid
#   inflating: content/midis/waltz_12.mid
#   inflating: content/midis/menuet.mid
#   inflating: content/midis/elephant.mid
#   inflating: content/midis/hmcello3.mid
#   inflating: content/midis/mazrka39.mid
#   inflating: content/midis/waltz_05.mid
#   inflating: content/midis/gondola.mid
#   inflating: content/midis/hemiones.mid
#   inflating: content/midis/scriabn4.mid
#   inflating: content/midis/mikro097.mid
#   inflating: content/midis/diary.mid
#   inflating: content/midis/peter.mid
#   inflating: content/midis/op6n08m5.mid
#   inflating: content/midis/gadflywaltz.mid
#   inflating: content/midis/chno4802.mid
#   inflating: content/midis/mnsnt05.mid
#   inflating: content/midis/gadflycontradance.mid
#   inflating: content/midis/polonais.mid
#   inflating: content/midis/op87_20b.mid
#   inflating: content/midis/chwa6401.mid
#   inflating: content/midis/vp1-2ald.mid
#   inflating: content/midis/purtrump.mid
#   inflating: content/midis/dsch10-4.mid
#   inflating: content/midis/op6n02m1.mid
#   inflating: content/midis/fugue_6.mid
#   inflating: content/midis/faurreq6.mid
#   inflating: content/midis/bag6_1.mid
#   inflating: content/midis/op6n06m5.mid
#   inflating: content/midis/rachbb.mid
#   inflating: content/midis/cmveder.mid
#   inflating: content/midis/chorus.mid
#   inflating: content/midis/herzlieb.mid
#   inflating: content/midis/sr15-8.mid
#   inflating: content/midis/chno1502.mid
#   inflating: content/midis/cs5-5gav.mid
#   inflating: content/midis/1_morng.mid
#   inflating: content/midis/bjsbmm08.mid
#   inflating: content/midis/mthop3-3.mid
#   inflating: content/midis/rach1-2.mid
#   inflating: content/midis/bwv792.mid
#   inflating: content/midis/se-fiera.mid
#   inflating: content/midis/bwv965.mid
#   inflating: content/midis/hary1.mid
#   inflating: content/midis/bwv846.mid
#   inflating: content/midis/heroica.mid
#   inflating: content/midis/mond.mid
#   inflating: content/midis/op6n06m4.mid
#   inflating: content/midis/canzone.mid
#   inflating: content/midis/hans3c.mid
#   inflating: content/midis/flute-1.mid
#   inflating: content/midis/bwv776.mid
#   inflating: content/midis/sm_mold.mid
#   inflating: content/midis/fasch.mid
#   inflating: content/midis/terzetto.mid
#   inflating: content/midis/bwv866.mid
#   inflating: content/midis/pmcastle.mid
#   inflating: content/midis/brahafov.mid
#   inflating: content/midis/weber-62.mid
#   inflating: content/midis/bjsbmm02.mid
#   inflating: content/midis/mikro131.mid
#   inflating: content/midis/op87_09b.mid
#   inflating: content/midis/chno5502.mid
#   inflating: content/midis/han-flsn.mid
#   inflating: content/midis/mazrka42.mid
#   inflating: content/midis/cap_24.mid
#   inflating: content/midis/bwv803.mid
#   inflating: content/midis/passag-.mid
#   inflating: content/midis/cs2-5men.mid
#   inflating: content/midis/bwv773.mid
#   inflating: content/midis/even.mid
#   inflating: content/midis/lttlef.mid
#   inflating: content/midis/mnsnt03.mid
#   inflating: content/midis/bwv810.mid
#   inflating: content/midis/hallujah.mid
#   inflating: content/midis/wachtauf.mid
#   inflating: content/midis/op87_08a.mid
#   inflating: content/midis/chet1001.mid
#   inflating: content/midis/op6n06gm.mid
#   inflating: content/midis/vp3-6gig.mid
#   inflating: content/midis/pagvar16.mid
#   inflating: content/midis/mthm107b.mid
#   inflating: content/midis/dim5.mid
#   inflating: content/midis/cs3-3cou.mid
#   inflating: content/midis/tiranno.mid
#   inflating: content/midis/dvs94.mid
#   inflating: content/midis/waltz_04.mid
#   inflating: content/midis/faurreq4.mid
#   inflating: content/midis/bwv794.mid
#   inflating: content/midis/strasop3.mid
#   inflating: content/midis/gf-prel.mid
#   inflating: content/midis/prkson64.mid
#   inflating: content/midis/op87_10b.mid
#   inflating: content/midis/mensy3-1.mid
#   inflating: content/midis/chno2702.mid
#   inflating: content/midis/mikro127.mid
#   inflating: content/midis/hum111-2.mid
#   inflating: content/midis/J_M_Bach_Auf_lasst_uns_den_Herren_loben.mid
#   inflating: content/midis/mthmop56.mid
#   inflating: content/midis/mikro145.mid
#   inflating: content/midis/bwv787.mid
#   inflating: content/midis/op87_19a.mid
#   inflating: content/midis/han_cha1.mid
#   inflating: content/midis/cs2-6gig.mid
#   inflating: content/midis/heavenly.mid
#   inflating: content/midis/mensy3-4.mid
#   inflating: content/midis/cs1-4sar.mid
#   inflating: content/midis/chopop28.mid
#   inflating: content/midis/india.mid
#   inflating: content/midis/gmin_c.mid
#   inflating: content/midis/flute-4.mid
#   inflating: content/midis/prtocc11.mid
#   inflating: content/midis/beeth3_2.mid
#   inflating: content/midis/men.mid
#   inflating: content/midis/purcell.mid
#   inflating: content/midis/msw47.mid
#   inflating: content/midis/mthmtrc2.mid
#   inflating: content/midis/mendel.mid
#   inflating: content/midis/mthmwo3c.mid
#   inflating: content/midis/wtellovr.mid
#   inflating: content/midis/lofty.mid
#   inflating: content/midis/bjsbmm09.mid
#   inflating: content/midis/bwv871.mid
#   inflating: content/midis/mazrka10.mid
#   inflating: content/midis/prmchick.mid
#   inflating: content/midis/forelle.mid
#   inflating: content/midis/bwv914.mid
#   inflating: content/midis/scenes.mid
#   inflating: content/midis/perlagloria.mid
#   inflating: content/midis/faurreq3.mid
#   inflating: content/midis/mapleaf.mid
#   inflating: content/midis/telmn-su.mid
#   inflating: content/midis/hwv333-3.mid
#   inflating: content/midis/bjsgig.mid
#   inflating: content/midis/6-4-4.mid
#   inflating: content/midis/gf-fuga.mid
#   inflating: content/midis/blest.mid
#   inflating: content/midis/weber1b.mid
#   inflating: content/midis/mvorfeo.mid
#   inflating: content/midis/op6n03m4.mid
#   inflating: content/midis/wedding.mid
#   inflating: content/midis/bwv971.mid
#   inflating: content/midis/hmmd-501.mid
#   inflating: content/midis/op8no4.mid
#   inflating: content/midis/mikro091.mid
#   inflating: content/midis/wtrmusic.mid
#   inflating: content/midis/bwv1060b.mid
#   inflating: content/midis/bjsbmm17.mid
#   inflating: content/midis/dansa.mid
#   inflating: content/midis/water1.mid
#   inflating: content/midis/glorygod.mid
#   inflating: content/midis/gf-carol.mid
#   inflating: content/midis/mthmvr75.mid
#   inflating: content/midis/bjsbmm15.mid
#   inflating: content/midis/gfh-jm30.mid
#   inflating: content/midis/schumn44.mid
#   inflating: content/midis/beetvc3.mid
#   inflating: content/midis/mndnoct.mid
#   inflating: content/midis/gfhcoro1.mid
#   inflating: content/midis/humm81m2.mid
#   inflating: content/midis/fantaisie.mid
#   inflating: content/midis/hary3.mid
#   inflating: content/midis/op87_02a.mid
#   inflating: content/midis/op6n08m6.mid
#   inflating: content/midis/scriabn1.mid
#   inflating: content/midis/han4-4c.mid
#   inflating: content/midis/ravotoc.mid
#   inflating: content/midis/va-tacit.mid
#   inflating: content/midis/intermez.mid
#   inflating: content/midis/bjss6a.mid
#   inflating: content/midis/stmatt.mid
#   inflating: content/midis/bart_see.mid
#   inflating: content/midis/beet27m1.mid
#   inflating: content/midis/vs3-2fug.mid
#   inflating: content/midis/bwv1032c.mid
#   inflating: content/midis/sch1-1.mid
#   inflating: content/midis/acttrag.mid
#   inflating: content/midis/asfrom.mid
#   inflating: content/midis/prludxii.mid
#   inflating: content/midis/han4-4b.mid
#   inflating: content/midis/vocalise.mid
#   inflating: content/midis/arabesqu.mid
#   inflating: content/midis/airnvari.mid
#   inflating: content/midis/gadflygalop.mid
#   inflating: content/midis/sr12-8.mid
#   inflating: content/midis/chno3202.mid
#   inflating: content/midis/d82.mid
#   inflating: content/midis/karmarch.mid
#   inflating: content/midis/mikro151.mid
#   inflating: content/midis/hums164.mid
#   inflating: content/midis/mnsnt09.mid
#   inflating: content/midis/op6n04m4.mid
#   inflating: content/midis/lbvar4.mid
#   inflating: content/midis/prokson3.mid
#   inflating: content/midis/humop1-1.mid
#   inflating: content/midis/mthmrf11.mid
#   inflating: content/midis/scipione.mid
#   inflating: content/midis/op5-3a.mid
#   inflating: content/midis/brand63.mid
#   inflating: content/midis/gfh-jm06.mid
#   inflating: content/midis/mthmtrc3.mid
#   inflating: content/midis/mthuo74a.mid
#   inflating: content/midis/rach0302.mid
#   inflating: content/midis/mthmscot.mid
#   inflating: content/midis/op87_22b.mid
#   inflating: content/midis/suite_1.mid
#   inflating: content/midis/bwv819.mid
#   inflating: content/midis/mthmwo4d.mid
#   inflating: content/midis/hungdan1.mid
#   inflating: content/midis/shos87-8.mid
#   inflating: content/midis/vp1-6sad.mid
#   inflating: content/midis/grosso3.mid
#   inflating: content/midis/mikro040.mid
#   inflating: content/midis/han4-5d.mid
#   inflating: content/midis/bwv915.mid
#   inflating: content/midis/boccher.mid
#   inflating: content/midis/mazrka06.mid
#   inflating: content/midis/makropulos.mid
#   inflating: content/midis/sonmv4.mid
#   inflating: content/midis/maz25n9.mid
#   inflating: content/midis/bwv807.mid
#   inflating: content/midis/liszt1-3.mid
#   inflating: content/midis/op6n03m1.mid
#   inflating: content/midis/op7n07m3.mid
#   inflating: content/midis/sonatina.mid
#   inflating: content/midis/bjsbmm04.mid
#   inflating: content/midis/op87_23b.mid
#   inflating: content/midis/beets3m2.mid
#   inflating: content/midis/cs1-3cou.mid
#   inflating: content/midis/pfc2-2.mid
#   inflating: content/midis/bjsbmm22.mid
#   inflating: content/midis/bwv811.mid
#   inflating: content/midis/cs5-2all.mid
#   inflating: content/midis/vs1-3sic.mid
#   inflating: content/midis/srop18.mid
#   inflating: content/midis/barbero.mid
#   inflating: content/midis/chet1006.mid
#   inflating: content/midis/bwv797.mid
#   inflating: content/midis/hums161.mid
#   inflating: content/midis/mikro123.mid
#   inflating: content/midis/stcmarch.mid
#   inflating: content/midis/cs5-4sar.mid
#   inflating: content/midis/eclipse.mid
#   inflating: content/midis/beeth9-2.mid
#   inflating: content/midis/lascia.mid
#   inflating: content/midis/bjsbmm23.mid
#   inflating: content/midis/sib244.mid
#   inflating: content/midis/cs4-3cou.mid
#   inflating: content/midis/trioson2.mid
#   inflating: content/midis/fugue_3.mid
#   inflating: content/midis/mikro153.mid
#   inflating: content/midis/han023.mid
#   inflating: content/midis/op87_07a.mid
#   inflating: content/midis/mazrka45.mid
#   inflating: content/midis/mikro152.mid
#   inflating: content/midis/jove.mid
#   inflating: content/midis/hpipe1.mid
#   inflating: content/midis/op6n09m1.mid
#   inflating: content/midis/humopph5.mid
#   inflating: content/midis/men-gon1.mid
#   inflating: content/midis/me38-2.mid
#   inflating: content/midis/op7n07m1.mid
#   inflating: content/midis/fantop49.mid
#   inflating: content/midis/sr15-1.mid
#   inflating: content/midis/mazrka49.mid
#   inflating: content/midis/6-4-3.mid
#   inflating: content/midis/pm1gnome.mid
#   inflating: content/midis/vp2-3sar.mid
#   inflating: content/midis/waltz_09.mid
#   inflating: content/midis/hums205.mid
#   inflating: content/midis/mazrka02.mid
#   inflating: content/midis/chaconng.mid
#   inflating: content/midis/babakiev.mid
#   inflating: content/midis/scrson5.mid
#   inflating: content/midis/holberg2.mid
#   inflating: content/midis/vp3-2lou.mid
#   inflating: content/midis/bwv910.mid
#   inflating: content/midis/op6n01m1.mid
#   inflating: content/midis/taoh24e2.mid
#   inflating: content/midis/overture.mid
#   inflating: content/midis/erbarme.mid
#   inflating: content/midis/bwv900.mid
#   inflating: content/midis/cara.mid
#   inflating: content/midis/meister.mid
#   inflating: content/midis/bartm153.mid
#   inflating: content/midis/brand3.mid
#   inflating: content/midis/cs2-3cou.mid
#   inflating: content/midis/mikro149.mid
#   inflating: content/midis/dvs92.mid
#   inflating: content/midis/op6n11m2.mid
#   inflating: content/midis/kodaly.mid
#   inflating: content/midis/sr15-9.mid
#   inflating: content/midis/lszt_ave.mid
#   inflating: content/midis/barmspc2.mid
#   inflating: content/midis/pianists.mid
#   inflating: content/midis/alborada.mid
#   inflating: content/midis/sync.mid
#   inflating: content/midis/mhqop87c.mid
#   inflating: content/midis/chet1011.mid
#   inflating: content/midis/gf-forl.mid
#   inflating: content/midis/vp1-4cod.mid
#   inflating: content/midis/me62-6.mid
#   inflating: content/midis/cmaj_d.mid
#   inflating: content/midis/vs3-3lar.mid
#   inflating: content/midis/dido.mid
#   inflating: content/midis/mikro143.mid
#   inflating: content/midis/dialogue.mid
#   inflating: content/midis/gfh-jm01.mid
#   inflating: content/midis/str-danc.mid
#   inflating: content/midis/bwv781.mid
#   inflating: content/midis/chet2507.mid
#   inflating: content/midis/clairdelune.mid
#   inflating: content/midis/vs1-4prs.mid
#   inflating: content/midis/jsbpassc.mid
#   inflating: content/midis/fantasyf.mid
#   inflating: content/midis/op87_11b.mid
#   inflating: content/midis/4_mtking.mid
#   inflating: content/midis/bwv878.mid
#   inflating: content/midis/bwv832.mid
#   inflating: content/midis/bwv808.mid
#   inflating: content/midis/chet2509.mid
#   inflating: content/midis/mnsnt08.mid
#   inflating: content/midis/sch-fan2.mid
#   inflating: content/midis/mthmwo4b.mid
#   inflating: content/midis/kommsues.mid
#   inflating: content/midis/walton3.mid
#   inflating: content/midis/btkco51a.mid
#   inflating: content/midis/humm_t7.mid
#   inflating: content/midis/cs3-6gig.mid
#   inflating: content/midis/trioson1.mid
#   inflating: content/midis/barpson3.mid
#   inflating: content/midis/bwv973.mid
#   inflating: content/midis/op6n06m2.mid
#   inflating: content/midis/sr15-3.mid
#   inflating: content/midis/rach1-3.mid
#   inflating: content/midis/pavane.mid
#   inflating: content/midis/mhqop87b.mid
#   inflating: content/midis/han-fir1.mid
#   inflating: content/midis/krejoice.mid
#   inflating: content/midis/bwv916.mid
#   inflating: content/midis/coriolan.mid
#   inflating: content/midis/viv_2t.mid
#   inflating: content/midis/op6n02m3.mid
#   inflating: content/midis/rondo.mid
#   inflating: content/midis/op87_15b.mid
#   inflating: content/midis/rachmm4.mid
#   inflating: content/midis/pur1.mid
#   inflating: content/midis/bwv798.mid
#   inflating: content/midis/vadoro.mid
#   inflating: content/midis/hmmdmp.mid
#   inflating: content/midis/beeth7_2.mid
#   inflating: content/midis/bag6_2.mid
#   inflating: content/midis/tarantel.mid
#   inflating: content/midis/bag6_5.mid
#   inflating: content/midis/dvs93.mid
#   inflating: content/midis/bjsair.mid
#   inflating: content/midis/han022.mid
#   inflating: content/midis/hung7.mid
#   inflating: content/midis/mthuso1b.mid
#   inflating: content/midis/op6n02m4.mid
#   inflating: content/midis/mazrka38.mid
#   inflating: content/midis/schumn22.mid
#   inflating: content/midis/op87_02b.mid
#   inflating: content/midis/suite_dm.mid
#   inflating: content/midis/flute-3.mid
#   inflating: content/midis/mendlvc1.mid
#   inflating: content/midis/bwv875.mid
#   inflating: content/midis/allegro.mid
#   inflating: content/midis/poem32n2.mid
#   inflating: content/midis/sr32_3.mid
#   inflating: content/midis/dmacbre1.mid
#   inflating: content/midis/op87_21a.mid
#   inflating: content/midis/elitsync.mid
#   inflating: content/midis/solace.mid
#   inflating: content/midis/bwv850.mid
#   inflating: content/midis/brahmsrp.mid
#   inflating: content/midis/mthm26c.mid
#   inflating: content/midis/mazrka15.mid
#   inflating: content/midis/humm81m1.mid
#   inflating: content/midis/mend_var.mid
#   inflating: content/midis/poultdp2.mid
#   inflating: content/midis/bwv812.mid
#   inflating: content/midis/bwv783.mid
#   inflating: content/midis/bwv791.mid
#   inflating: content/midis/fmaj_a.mid
#   inflating: content/midis/han-ct-2.mid
#   inflating: content/midis/bag6_3.mid
#   inflating: content/midis/men-gon2.mid
#   inflating: content/midis/mthmopp9.mid
#   inflating: content/midis/bwv827.mid
#   inflating: content/midis/vs2-1gra.mid
#   inflating: content/midis/bwv809.mid
#   inflating: content/midis/pr37n3.mid
#   inflating: content/midis/pathet1.mid
#   inflating: content/midis/bwv855.mid
#   inflating: content/midis/pfc2-1.mid
#   inflating: content/midis/op6n09m2.mid
#   inflating: content/midis/lbvar3.mid
#   inflating: content/midis/bwv796.mid
#   inflating: content/midis/bwv829.mid
#   inflating: content/midis/mazrka21.mid
#   inflating: content/midis/bwv972.mid
#   inflating: content/midis/chno3702.mid
#   inflating: content/midis/arobusto.mid
#   inflating: content/midis/op6n09m6.mid
#   inflating: content/midis/btkconc1.mid
#   inflating: content/midis/whatpass.mid
#   inflating: content/midis/mazrka46.mid
#   inflating: content/midis/op42no6.mid
#   inflating: content/midis/humop101.mid
#   inflating: content/midis/bwv862.mid
#   inflating: content/midis/cs3-4sar.mid
#   inflating: content/midis/bwv895.mid
#   inflating: content/midis/racine.mid
#   inflating: content/midis/mazrka13.mid
#   inflating: content/midis/humm109a.mid
#   inflating: content/midis/sr15-11.mid
#   inflating: content/midis/humop122.mid
#   inflating: content/midis/op6n07m3.mid
#   inflating: content/midis/han021.mid
#   inflating: content/midis/sch-fan1.mid
#   inflating: content/midis/dsch10-1.mid
#   inflating: content/midis/sr12-4.mid
#   inflating: content/midis/bwv789.mid
#   inflating: content/midis/mazeppa.mid
#   inflating: content/midis/enigma.mid
#   inflating: content/midis/barpson2.mid
#   inflating: content/midis/ldmesse1.mid
#   inflating: content/midis/mephisto.mid
#   inflating: content/midis/mikro150.mid
#   inflating: content/midis/taoh24e4.mid
#   inflating: content/midis/lindbaum.mid
#   inflating: content/midis/blumnstk.mid
#   inflating: content/midis/bwv772.mid
#   inflating: content/midis/bwv867.mid
#   inflating: content/midis/aria5.mid
#   inflating: content/midis/pgvr1617.mid
#   inflating: content/midis/hummop23.mid
#   inflating: content/midis/op6n07m4.mid
#   inflating: content/midis/locean.mid
#   inflating: content/midis/bwv786.mid
#   inflating: content/midis/brand43s.mid
#   inflating: content/midis/earlking.mid
#   inflating: content/midis/mikro136.mid
#   inflating: content/midis/bwv899.mid
#   inflating: content/midis/humorsk1.mid
#   inflating: content/midis/handelcm.mid
#   inflating: content/midis/motion.mid
#   inflating: content/midis/bwv815.mid
#   inflating: content/midis/suite_4.mid
#   inflating: content/midis/mthmwo3b.mid
#   inflating: content/midis/brondo.mid
#   inflating: content/midis/hans6a.mid
#   inflating: content/midis/mikro073.mid
#   inflating: content/midis/aquarium.mid
#   inflating: content/midis/flute-5.mid
#   inflating: content/midis/hary2.mid
#   inflating: content/midis/hain_gs.mid
#   inflating: content/midis/bjsbmm01.mid
#   inflating: content/midis/bjsfanam.mid
#   inflating: content/midis/mthm107a.mid
#   inflating: content/midis/siclienn.mid
#   inflating: content/midis/fmaj_b.mid
#   inflating: content/midis/bwv828.mid
#   inflating: content/midis/vp1-8tbd.mid
#   inflating: content/midis/op42no5.mid
#   inflating: content/midis/widmund.mid
#   inflating: content/midis/gnossie4.mid
#   inflating: content/midis/op6n08m1.mid
#   inflating: content/midis/mikro083.mid
#   inflating: content/midis/satsara1.mid
#   inflating: content/midis/moments1.mid
#   inflating: content/midis/sonet104.mid
#   inflating: content/midis/gfh-jm18.mid
#   inflating: content/midis/bjsbmm12.mid
#   inflating: content/midis/hmmd-302.mid
#   inflating: content/midis/stc-over.mid
#   inflating: content/midis/op87_16a.mid
#   inflating: content/midis/drinking.mid
#   inflating: content/midis/waltz_02.mid
#   inflating: content/midis/russrap.mid
#   inflating: content/midis/op87_05a.mid
#   inflating: content/midis/bwv857.mid
#   inflating: content/midis/han-fir3.mid
#   inflating: content/midis/op6n07m5.mid
#   inflating: content/midis/op87_19b.mid
#   inflating: content/midis/bwv993.mid
#   inflating: content/midis/osleep.mid
#   inflating: content/midis/vp2-2cou.mid
#   inflating: content/midis/sr28-2.mid
#   inflating: content/midis/waltz_10.mid
#   inflating: content/midis/poultdp1.mid
#   inflating: content/midis/waltz_14.mid
#   inflating: content/midis/mnsnt07.mid
#   inflating: content/midis/beevar2.mid
#   inflating: content/midis/furelise.mid
#   inflating: content/midis/mazrka20.mid
#   inflating: content/midis/bwv818.mid
#   inflating: content/midis/brand62.mid
#   inflating: content/midis/bwv-902.mid
#   inflating: content/midis/op6n02m2.mid
#   inflating: content/midis/humop7-2.mid
#   inflating: content/midis/mazrka07.mid
#   inflating: content/midis/sr15-13.mid
#   inflating: content/midis/hmmd1-201.mid
#   inflating: content/midis/gp_2ital.mid
#   inflating: content/midis/o-haupt.mid
#   inflating: content/midis/2_ase.mid
#   inflating: content/midis/sch2-3.mid
#   inflating: content/midis/chpson3c.mid
#   inflating: content/midis/op6n01m3.mid
#   inflating: content/midis/feux.mid
#   inflating: content/midis/faurreq2.mid
#   inflating: content/midis/bart33gm.mid
#   inflating: content/midis/bwv874.mid
#   inflating: content/midis/dovesei.mid
#   inflating: content/midis/han024.mid
#   inflating: content/midis/poulcmo2.mid
#   inflating: content/midis/hans3b.mid
#   inflating: content/midis/chno3701.mid
#   inflating: content/midis/chwa18.mid
#   inflating: content/midis/italian1.mid
#   inflating: content/midis/preldo.mid
#   inflating: content/midis/ausliebe.mid
#   inflating: content/midis/gnoss.mid
#   inflating: content/midis/blute.mid
#   inflating: content/midis/hndl_var.mid
#   inflating: content/midis/hindbsn3.mid
#   inflating: content/midis/ruprecht.mid
#   inflating: content/midis/fugue_2.mid
#   inflating: content/midis/op6n01m4.mid
#   inflating: content/midis/op6n09m3.mid
#   inflating: content/midis/waltz_11.mid
#   inflating: content/midis/btvn-rnd.mid
#   inflating: content/midis/kinder1.mid
#   inflating: content/midis/bwv859.mid
#   inflating: content/midis/bali.mid
#   inflating: content/midis/pmarkcat.mid
#   inflating: content/midis/lszt_vi.mid
#   inflating: content/midis/sho_fd_3.mid
#   inflating: content/midis/bwv779.mid
#   inflating: content/midis/chet1007.mid
#   inflating: content/midis/cs3-5bou.mid
#   inflating: content/midis/bjsbmm16.mid
#   inflating: content/midis/op87_18a.mid
#   inflating: content/midis/op6n06m3.mid
#   inflating: content/midis/bwv823.mid
#   inflating: content/midis/chno6201.mid
#   inflating: content/midis/sib2-34.mid
#   inflating: content/midis/mazrka48.mid
#   inflating: content/midis/bwv1032a.mid
#   inflating: content/midis/bumbleb.mid
#   inflating: content/midis/mthmop2a.mid
#   inflating: content/midis/mthmwo3a.mid
#   inflating: content/midis/father.mid
#   inflating: content/midis/villa.mid
#   inflating: content/midis/orphan.mid
#   inflating: content/midis/6-4-1.mid
#   inflating: content/midis/etud42_5.mid
#   inflating: content/midis/bwv975.mid
#   inflating: content/midis/haydnvar.mid
#   inflating: content/midis/op87_24a.mid
#   inflating: content/midis/cs2-2all.mid
#   inflating: content/midis/han-fir2.mid
#   inflating: content/midis/humm_t6.mid
#   inflating: content/midis/rsch31.mid
#   inflating: content/midis/sicilien.mid
#   inflating: content/midis/wewill.mid
#   inflating: content/midis/scherzo.mid.mid
#   inflating: content/midis/bwv985.mid
#   inflating: content/midis/cs1-5men.mid
#   inflating: content/midis/bwv851.mid
#   inflating: content/midis/srhapfa.mid
#   inflating: content/midis/op6n10m6.mid
#   inflating: content/midis/brand5.mid
#   inflating: content/midis/sr12-3.mid
#   inflating: content/midis/mikro142.mid
#   inflating: content/midis/humm_pf.mid
#   inflating: content/midis/cs6-1pre.mid
#   inflating: content/midis/poultdp3.mid
#   inflating: content/midis/cs1-2all.mid
#   inflating: content/midis/gymnop02.mid
#   inflating: content/midis/ital-4.mid
#   inflating: content/midis/mahl4_4.mid
#   inflating: content/midis/cs4-2all.mid
#   inflating: content/midis/bwv913.mid
#   inflating: content/midis/chet2512.mid
#   inflating: content/midis/mazrka22.mid
#   inflating: content/midis/sr12-1.mid
#   inflating: content/midis/menj.mid
#   inflating: content/midis/imprmtu3.mid
#   inflating: content/midis/gmin_d.mid
#   inflating: content/midis/cs5-3cou.mid
#   inflating: content/midis/chwapsth.mid
#   inflating: content/midis/sheep.mid
#   inflating: content/midis/deb_clar.mid
#   inflating: content/midis/mnsnt00.mid
#   inflating: content/midis/goldberg.mid
#   inflating: content/midis/humop41o.mid
#   inflating: content/midis/beets3m4.mid
#   inflating: content/midis/bwv983.mid
#   inflating: content/midis/pagavar7.mid
#   inflating: content/midis/bwv881.mid
#   inflating: content/midis/mthuo74c.mid
#   inflating: content/midis/aria14.mid
#   inflating: content/midis/bwv876.mid
#   inflating: content/midis/vp3-3gav.mid
#   inflating: content/midis/bwv805.mid
#   inflating: content/midis/bartm140.mid
#   inflating: content/midis/scriabn3.mid
#   inflating: content/midis/bwv869.mid
#   inflating: content/midis/mazrka23.mid
#   inflating: content/midis/swwo30n1.mid
#   inflating: content/midis/messiah.mid
#   inflating: content/midis/humop47.mid
#   inflating: content/midis/nocturn4.mid
#   inflating: content/midis/bartsche.mid
#   inflating: content/midis/mthm26d.mid
#   inflating: content/midis/mnsnt12.mid
#   inflating: content/midis/mthm107c.mid
#   inflating: content/midis/jk_web78.mid
#   inflating: content/midis/pgvr1115.mid
#   inflating: content/midis/jshcg655.mid
#   inflating: content/midis/bjsbb21.mid
#   inflating: content/midis/rustle.mid
#   inflating: content/midis/mikro082.mid
#   inflating: content/midis/gfh-jm04.mid
#   inflating: content/midis/blksmith.mid
#   inflating: content/midis/kangaroo.mid
#   inflating: content/midis/trumpet.mid
#   inflating: content/midis/jshcg651.mid
#   inflating: content/midis/sr12-7.mid
#   inflating: content/midis/hmmtop94.mid
#   inflating: content/midis/bwv912.mid
#   inflating: content/midis/jsbtafc.mid
#   inflating: content/midis/bwv870.mid
#   inflating: content/midis/mahl4_2.mid
#   inflating: content/midis/vs2-4alg.mid
#   inflating: content/midis/amin_d.mid
#   inflating: content/midis/waltz_07.mid
#   inflating: content/midis/op87_22a.mid
#   inflating: content/midis/op87_17a.mid
#   inflating: content/midis/pathet3.mid
#   inflating: content/midis/bear-dnc.mid
#   inflating: content/midis/lszt_pg1.mid
#   inflating: content/midis/humop7-1.mid
#   inflating: content/midis/trioson3.mid
#   inflating: content/midis/tlmnflut.mid
#   inflating: content/midis/gladiols.mid
#   inflating: content/midis/konnen.mid
#   inflating: content/midis/mthop3-2.mid
#   inflating: content/midis/barpson1.mid
#   inflating: content/midis/noctuell.mid
#   inflating: content/midis/hum5.mid
#   inflating: content/midis/lbvar1.mid
#   inflating: content/midis/bolero.mid
#   inflating: content/midis/men-gon3.mid
#   inflating: content/midis/op87_08b.mid
#   inflating: content/midis/fuguexii.mid
#   inflating: content/midis/bwv835.mid
#   inflating: content/midis/chet1003.mid
#   inflating: content/midis/mikro122.mid
#   inflating: content/midis/amin_a.mid
#   inflating: content/midis/op87_09a.mid
#   inflating: content/midis/menop64a.mid
#   inflating: content/midis/mazrka29.mid
#   inflating: content/midis/lisztanz.mid
#   inflating: content/midis/chet1005.mid
#   inflating: content/midis/mazrka09.mid
#   inflating: content/midis/mthmop18.mid
#   inflating: content/midis/mazrka41.mid
#   inflating: content/midis/walton1.mid
#   inflating: content/midis/burlesq1.mid
#   inflating: content/midis/strasop2.mid
#   inflating: content/midis/intruder.mid
#   inflating: content/midis/cs3-1pre.mid
#   inflating: content/midis/kinder3.mid
#   inflating: content/midis/sonmv1.mid
#   inflating: content/midis/fromharm.mid
#   inflating: content/midis/fnlandia.mid
#   inflating: content/midis/op87_04a.mid
#   inflating: content/midis/mthupo70.mid
#   inflating: content/midis/humop1-2.mid
#   inflating: content/midis/bwv800.mid
#   inflating: content/midis/op87_16b.mid
#   inflating: content/midis/hindbsn1.mid
#   inflating: content/midis/mthm26a.mid
#   inflating: content/midis/bwv790.mid
#   inflating: content/midis/btkconc4.mid
#   inflating: content/midis/mazrka44.mid
#   inflating: content/midis/imperial.mid
#   inflating: content/midis/msw14.mid
#   inflating: content/midis/mnsnt11.mid
#   inflating: content/midis/cs6-5gav.mid
#   inflating: content/midis/mazrka31.mid
#   inflating: content/midis/sr12-5.mid
#   inflating: content/midis/op8no12.mid
#   inflating: content/midis/hmwoo23a.mid
#   inflating: content/midis/humm109.mid
#   inflating: content/midis/bwv804.mid
#   inflating: content/midis/vp1-7tb.mid
#   inflating: content/midis/mazrka28.mid
#   inflating: content/midis/pgvr1924.mid
#   inflating: content/midis/sr15-2.mid
#   inflating: content/midis/lbvar6ep.mid
#   inflating: content/midis/hungdan5.mid
#   inflating: content/midis/slav46_4.mid
#   inflating: content/midis/bwv988.mid
#   inflating: content/midis/pre-cavr.mid
#   inflating: content/midis/han4-6a.mid
#   inflating: content/midis/strasop1.mid
#   inflating: content/midis/destino.mid
#   inflating: content/midis/poulecoq.mid
#   inflating: content/midis/griewdat.mid
#   inflating: content/midis/bwv868.mid
#   inflating: content/midis/fugue_4.mid
#   inflating: content/midis/menop64c.mid
#   inflating: content/midis/lszt_hr2.mid
#   inflating: content/midis/chet1002.mid
#   inflating: content/midis/tristan.mid
#   inflating: content/midis/sr15-10.mid
#   inflating: content/midis/op7n07m4.mid
#   inflating: content/midis/mazrka33.mid
#   inflating: content/midis/dsch10-3.mid
#   inflating: content/midis/gebtmir.mid
#   inflating: content/midis/bwv841.mid
#   inflating: content/midis/vs1-2fug.mid
#   inflating: content/midis/lszt_et3.mid
#   inflating: content/midis/jeuxdeau.mid
#   inflating: content/midis/op6n04m1.mid
#   inflating: content/midis/op87_06b.mid
#   inflating: content/midis/mazrka16.mid
#   inflating: content/midis/intrlude.mid
#   inflating: content/midis/bwv863.mid
#   inflating: content/midis/bwv777.mid
#   inflating: content/midis/mazrka14.mid
#   inflating: content/midis/bwv979.mid
#   inflating: content/midis/prkson63.mid
#   inflating: content/midis/rach_op30_2.mid
#   inflating: content/midis/hans6b.mid
#   inflating: content/midis/bjsbmm06.mid
#   inflating: content/midis/waltz_06.mid
#   inflating: content/midis/bwv826.mid
#   inflating: content/midis/chet2511.mid
#   inflating: content/midis/hndl-alm.mid
#   inflating: content/midis/vp2-1all.mid
#   inflating: content/midis/mazrka18.mid
#   inflating: content/midis/aria140.mid
#   inflating: content/midis/miocaro.mid
#   inflating: content/midis/bwv981.mid
#   inflating: content/midis/bwv806.mid
#   inflating: content/midis/chet2506.mid
#   inflating: content/midis/mazrka27.mid
#   inflating: content/midis/gnossie5.mid
#   inflating: content/midis/mikro148.mid
#   inflating: content/midis/chno4801.mid
#   inflating: content/midis/3_anitra.mid
#   inflating: content/midis/op6n07m2.mid
#   inflating: content/midis/bjsbmm03.mid
#   inflating: content/midis/op87_01b.mid
#   inflating: content/midis/coumoiss.mid
#   inflating: content/midis/hum3impr.mid
#   inflating: content/midis/wtrmsic.mid
#   inflating: content/midis/brand22.mid
#   inflating: content/midis/cmaj_e.mid
#   inflating: content/midis/festivgm
#   inflating: content/midis/valse.mid
#   inflating: content/midis/bwv989.mid
#   inflating: content/midis/op6n10m3.mid
#   inflating: content/midis/chpson3b.mid
#   inflating: content/midis/mthuo74d.mid
#   inflating: content/midis/op7n07m5.mid
#   inflating: content/midis/vp2-5cha.mid
#   inflating: content/midis/jsdpet1.mid
#   inflating: content/midis/gmin_a.mid
#   inflating: content/midis/rach_op30_1.mid
#   inflating: content/midis/poulcmo4.mid
#   inflating: content/midis/pagava.mid
#   inflating: content/midis/shos34-6.mid
#   inflating: content/midis/cmaj_b.mid
#   inflating: content/midis/op87_06a.mid
#   inflating: content/midis/brand23.mid
#   inflating: content/midis/op87_05b.mid
#   inflating: content/midis/op87_14a.mid
#   inflating: content/midis/chno6202.mid
#   inflating: content/midis/cs4-4sar.mid
#   inflating: content/midis/cs6-6gig.mid
#   inflating: content/midis/bwv825.mid
#   inflating: content/midis/dorian.mid
#   inflating: content/midis/gymnop01.mid
#   inflating: content/midis/mephist2.mid
#   inflating: content/midis/bourree.mid
#   inflating: content/midis/pianocon.mid
#   inflating: content/midis/mazrka04.mid
#   inflating: content/midis/sarabnde.mid
#   inflating: content/midis/aufburg.mid
#   inflating: content/midis/rach2305.mid
#   inflating: content/midis/cygne.mid
#   inflating: content/midis/sch_ave.mid
#   inflating: content/midis/bart_bag.mid
#   inflating: content/midis/op6n07m1.mid
#   inflating: content/midis/op6n06m1.mid
#   inflating: content/midis/op6n08m2.mid
#   inflating: content/midis/jsdpet2.mid
#   inflating: content/midis/o-savior.mid
#   inflating: content/midis/scrsym32.mid
#   inflating: content/midis/pagavar8.mid
#   inflating: content/midis/bjsbmm05.mid
#   inflating: content/midis/hans6d.mid
#   inflating: content/midis/beeth9-3.mid
#   inflating: content/midis/op42no1.mid
#   inflating: content/midis/gadflyromance.mid
#   inflating: content/midis/han4-6c.mid

# %%
filenames = glob.glob("/content/content/midis/*.mid")
print('Number of files:', len(filenames))
# Out:
# Number of files: 1325

# %% [markdown]
# ## Process a MIDI file

# %% [markdown]
# First, use ```pretty_midi``` to parse a single MIDI file and inspect the format of the notes.

# %%
sample_file = filenames[1]
# sample_file = "/content/for_elise_by_beethoven.mid"
print(sample_file)
# Out:
# /content/content/midis/blute.mid

# %% [markdown]
# Generate a `PrettyMIDI` object for the sample MIDI file.

# %%
pm = pretty_midi.PrettyMIDI(sample_file)
pm
# Out:
# /usr/local/lib/python3.10/dist-packages/pretty_midi/pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(

# %% [markdown]
# Play the sample file.

# %%
def display_audio(pm: pretty_midi.PrettyMIDI, seconds=30):
  waveform = pm.fluidsynth(fs=_SAMPLING_RATE)
  # Take a sample of the generated waveform to mitigate kernel resets
  waveform_short = waveform[:seconds*_SAMPLING_RATE]
  return display.Audio(waveform_short, rate=_SAMPLING_RATE)

# %%
display_audio(pm)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Do some inspection on the MIDI file.

# %%
print('Number of instruments:', len(pm.instruments))
instrument = pm.instruments[0]
instrument_name = pretty_midi.program_to_instrument_name(instrument.program)
print('Instrument name:', instrument_name)
# Out:
# Number of instruments: 8
# Instrument name: Oboe

# %% [markdown]
# ## Extract notes

# %%
for i, note in enumerate(instrument.notes[:10]):
  note_name = pretty_midi.note_number_to_name(note.pitch)
  duration = note.end - note.start
  print(f'{i}: pitch={note.pitch}, note_name={note_name},'
        f' duration={duration:.4f}')
# Out:
# 0: pitch=82, note_name=A#5, duration=0.1639
# 1: pitch=87, note_name=D#6, duration=0.1639
# 2: pitch=87, note_name=D#6, duration=0.1639
# 3: pitch=82, note_name=A#5, duration=0.1639
# 4: pitch=82, note_name=A#5, duration=0.6917
# 5: pitch=84, note_name=C6, duration=0.3583
# 6: pitch=86, note_name=D6, duration=0.3306
# 7: pitch=87, note_name=D#6, duration=0.6917
# 8: pitch=91, note_name=G6, duration=0.3583
# 9: pitch=87, note_name=D#6, duration=0.6917

# %% [markdown]
# 3 variables to represent a note when training the model: `pitch`, `step` and `duration`. The pitch is the perceptual quality of the sound as a MIDI note number.
# The `step` is the time elapsed from the previous note or start of the track.
# The `duration` is how long the note will be playing in seconds and is the difference between the note end and note start times.

# %% [markdown]
# Extract the notes from the sample MIDI file.

# %%
def midi_to_notes(midi_file: str) -> pd.DataFrame:
  pm = pretty_midi.PrettyMIDI(midi_file)
  instrument = pm.instruments[0]
  notes = collections.defaultdict(list)

  # Sort the notes by start time
  sorted_notes = sorted(instrument.notes, key=lambda note: note.start)
  prev_start = sorted_notes[0].start

  for note in sorted_notes:
    start = note.start
    end = note.end
    notes['pitch'].append(note.pitch)
    notes['start'].append(start)
    notes['end'].append(end)
    notes['step'].append(start - prev_start)
    notes['duration'].append(end - start)
    prev_start = start

  return pd.DataFrame({name: np.array(value) for name, value in notes.items()})

# %%
raw_notes = midi_to_notes(sample_file)
raw_notes.head()
# Out:
#    pitch      start        end      step  duration
# 0     71  25.263136  25.649649  0.000000  0.386513
# 1     73  25.657872  26.439122  0.394736  0.781249
# 2     70  26.447346  26.833858  0.789473  0.386513
# 3     71  26.842082  27.623331  0.394737  0.781249
# 4     74  31.578920  31.965433  4.736838  0.386513

# %%
raw_notes.tail()
# Out:
#       pitch       start         end      step  duration
# 1063     71  165.642885  165.857170  0.214286  0.214286
# 1064     45  165.857170  167.142885  0.214286  1.285715
# 1065     33  165.857170  167.142885  0.000000  1.285715
# 1066     60  165.857170  167.142885  0.000000  1.285715
# 1067     69  165.857170  167.142885  0.000000  1.285715

# %% [markdown]
# To more easily interpret pitches, I'll convert them to note names rather than the pitches.
# The note name shows the type of note, accidental and octave number
# (e.g. C#4).

# %%
get_note_names = np.vectorize(pretty_midi.note_number_to_name)
sample_note_names = get_note_names(raw_notes['pitch'])
sample_note_names[:10]
# Out:
# array(['B4', 'C#5', 'A#4', 'B4', 'D5', 'E5', 'C#5', 'D5', 'F5', 'E5'],
#       dtype='<U3')

# %% [markdown]
# To visualize the musical piece, plot the note pitch, start and end across the length of the track (i.e. piano roll). Start with the first 100 notes

# %%
def plot_piano_roll(notes: pd.DataFrame, count: Optional[int] = None):
  if count:
    title = f'First {count} notes'
  else:
    title = f'Whole track'
    count = len(notes['pitch'])
  plt.figure(figsize=(20, 4))
  plot_pitch = np.stack([notes['pitch'], notes['pitch']], axis=0)
  plot_start_stop = np.stack([notes['start'], notes['end']], axis=0)
  plt.plot(
      plot_start_stop[:, :count], plot_pitch[:, :count], color="b", marker=".")
  plt.xlabel('Time [s]')
  plt.ylabel('Pitch')
  _ = plt.title(title)

# %%
plot_piano_roll(raw_notes, count=100)

# %% [markdown]
# Plot the notes for the entire track.

# %%
plot_piano_roll(raw_notes)

# %% [markdown]
# Check the distribution of each note variable.

# %%
def plot_distributions(notes: pd.DataFrame, drop_percentile=2.5):
  plt.figure(figsize=[15, 5])
  plt.subplot(1, 3, 1)
  sns.histplot(notes, x="pitch", bins=20)

  plt.subplot(1, 3, 2)
  max_step = np.percentile(notes['step'], 100 - drop_percentile)
  sns.histplot(notes, x="step", bins=np.linspace(0, max_step, 21))

  plt.subplot(1, 3, 3)
  max_duration = np.percentile(notes['duration'], 100 - drop_percentile)
  sns.histplot(notes, x="duration", bins=np.linspace(0, max_duration, 21))

# %%
plot_distributions(raw_notes)

# %% [markdown]
# ## Create the training dataset

# %% [markdown]
# Create the training dataset by extracting notes from the MIDI files.

# %%
# %%time
# num_files = 5
all_notes = []
# temp = ["/content/for_elise_by_beethoven.mid"]
for f in filenames:

# for f in filenames[:num_files]:
# for f in temp:
    try:
        notes = midi_to_notes(f)
    except Exception as e:
        print(e)
        print(f)
        continue
    all_notes.append(notes)

# %%
len(filenames), len(all_notes)
# Out:
# (1325, 1235)

# %%
for i in all_notes:
    if i.shape[0] == 0:
        print(i)
    if i.shape[1] != 5:
        print(i)

# %%
# connect to your drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# file_path = '/content/drive/MyDrive/Springboard/Capstone 3/all_notes.csv'

# all_notes = pd.read_csv(file_path).drop(columns=['Unnamed: 0'])
# all_notes.head()

# %%
all_notes = pd.concat(all_notes)
all_notes
# Out:
#     pitch      start        end      step  duration
# 0      39   2.000000   5.737980  0.000000  3.737980
# 1      43   5.749999   5.882211  3.749999  0.132212
# 2      46   5.894230   6.026442  0.144231  0.132212
# 3      51   6.038461   6.170673  0.144231  0.132212
# 4      55   6.182692   6.314903  0.144231  0.132212
# ..    ...        ...        ...       ...       ...
# 52     65  68.858073  69.494792  1.218750  0.636719
# 53     65  69.497396  69.964844  0.639323  0.467448
# 54     65  69.967448  70.506510  0.470052  0.539062
# 55     65  70.808594  74.108073  0.841146  3.299479
# 56     41  70.808594  74.108073  0.000000  3.299479
#
# [1570367 rows x 5 columns]

# %%
all_notes.isna().sum()
# Out:
# pitch       0
# start       0
# end         0
# step        0
# duration    0
# dtype: int64

# %%
# descriptive statistics
all_notes.describe()
# Out:
#               pitch         start           end          step      duration
# count  1.570367e+06  1.570367e+06  1.570367e+06  1.570367e+06  1.570367e+06
# mean   6.692555e+01  3.055207e+02  3.057959e+02  2.203416e-01  2.752374e-01
# std    1.267325e+01  3.558646e+02  3.558575e+02  1.327640e+00  4.282579e-01
# min    0.000000e+00  0.000000e+00  3.472219e-02  0.000000e+00  5.990104e-04
# 25%    5.900000e+01  7.850228e+01  7.879384e+01  3.676467e-03  9.791667e-02
# 50%    6.800000e+01  1.812500e+02  1.815354e+02  1.083333e-01  1.541667e-01
# 75%    7.600000e+01  3.936678e+02  3.939444e+02  2.142855e-01  2.916664e-01
# max    1.190000e+02  3.304736e+03  3.306611e+03  7.240340e+02  9.971144e+01

# %%
# plot distributions
# Creating a KDE plot for each column
for column in all_notes.columns:
    plt.figure(figsize=(10, 6))
    sns.kdeplot(data=all_notes, x=column, fill=True)
    plt.title(f'KDE Plot of {column.capitalize()}')
    plt.xlabel(column.capitalize())
    plt.ylabel('Density')
    plt.show()

# %% [markdown]
# - So obviously step and duration are significantly positively skewed.. which is expected I believe.

# %% [markdown]
# - Check correlation

# %%
sns.heatmap(all_notes.corr());
# Out:
# <Axes: >

# %% [markdown]
# - As expected, not much relation between the variables

# %%
all_notes.to_csv('all_notes.csv')

# %% [markdown]
# - Copy the dataset to Google Drive

# %%
# !cp /content/all_notes.csv '/content/drive/MyDrive/Springboard/Capstone 3/'

# %%
n_notes = len(all_notes)
print('Number of notes parsed:', n_notes)
# Out:
# Number of notes parsed: 1570367
